# %% [markdown]
# # Librarys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset.csv", parse_dates=None)

# %%
df.head()
# Out:
#              id   age  monthly_income  ...  gender  utm_term education_level
# 0  100001025857  61.0          1300.0  ...    male       NaN             NaN
# 1        173466  50.0          3500.0  ...     NaN         c             NaN
# 2        173465  31.0          2600.0  ...    male       NaN             NaN
# 3        173464  51.0          3600.0  ...    male       NaN             NaN
# 4        173463  51.0          1500.0  ...    male       NaN             NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# # Description variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35021 entries, 0 to 35020
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    35021 non-null  int64
#  1   age                   35019 non-null  float64
#  2   monthly_income        35019 non-null  float64
#  3   collateral_value      35000 non-null  float64
#  4   loan_amount           35018 non-null  float64
#  5   city                  34998 non-null  object
#  6   state                 35017 non-null  object
#  7   collateral_debt       24650 non-null  float64
#  8   verified_restriction  26329 non-null  float64
#  9   dishonored_checks     35021 non-null  int64
#  10  expired_debts         35021 non-null  int64
#  11  banking_debts         35021 non-null  int64
#  12  commercial_debts      35021 non-null  int64
#  13  protests              35021 non-null  int64
#  14  marital_status        415 non-null    object
#  15  informed_restriction  33371 non-null  float64
#  16  loan_term             0 non-null      float64
#  17  monthly_payment       33739 non-null  float64
#  18  informed_purpose      33904 non-null  object
#  19  auto_brand            35012 non-null  object
#  20  auto_model            35010 non-null  object
#  21  auto_year             35017 non-null  float64
#  22  pre_approved          34848 non-null  float64
#  23  form_completed        34846 non-null  float64
#  24  sent_to_analysis      34848 non-null  float64
#  25  channel               33734 non-null  object
#  26  zip_code              35021 non-null  object
#  27  landing_page          33734 non-null  object
#  28  landing_page_product  22929 non-null  object
#  29  gender                31077 non-null  object
#  30  utm_term              11207 non-null  object
#  31  education_level       19894 non-null  object
# dtypes: float64(13), int64(6), object(13)
# memory usage: 8.6+ MB

# %%
df.isnull().sum()
# Out:
# id                          0
# age                         2
# monthly_income              2
# collateral_value           21
# loan_amount                 3
# city                       23
# state                       4
# collateral_debt         10371
# verified_restriction     8692
# dishonored_checks           0
# expired_debts               0
# banking_debts               0
# commercial_debts            0
# protests                    0
# marital_status          34606
# informed_restriction     1650
# loan_term               35021
# monthly_payment          1282
# informed_purpose         1117
# auto_brand                  9
# auto_model                 11
# auto_year                   4
# pre_approved              173
# form_completed            175
# sent_to_analysis          173
# channel                  1287
# zip_code                    0
# landing_page             1287
# landing_page_product    12092
# gender                   3944
# utm_term                23814
# education_level         15127
# dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Var dependente: sent_to_analysis

# %%
df.nunique().sort_values()
# Out:
# loan_term                   0
# informed_restriction        2
# gender                      2
# sent_to_analysis            2
# form_completed              2
# pre_approved                2
# verified_restriction        2
# dishonored_checks           2
# expired_debts               2
# banking_debts               2
# commercial_debts            2
# protests                    2
# utm_term                    3
# marital_status              6
# landing_page_product        7
# education_level             9
# channel                    10
# state                      27
# auto_year                  34
# auto_brand                 73
# age                        80
# landing_page              269
# collateral_debt          1490
# loan_amount              1505
# auto_model               2634
# monthly_income           2686
# collateral_value         2866
# monthly_payment          3417
# city                     3986
# zip_code                 5709
# informed_purpose        17668
# id                      35017
# dtype: int64

# %%
df.describe()
# Out:
#                  id           age  ...  form_completed  sent_to_analysis
# count  3.502100e+04  35019.000000  ...    34846.000000      34848.000000
# mean   3.000538e+06     38.325338  ...        0.260546          0.093807
# std    5.343669e+08     11.576323  ...        0.438939          0.291565
# min    9.832600e+04     18.000000  ...        0.000000          0.000000
# 25%    1.332740e+05     30.000000  ...        0.000000          0.000000
# 50%    1.464430e+05     36.000000  ...        0.000000          0.000000
# 75%    1.601360e+05     46.000000  ...        1.000000          0.000000
# max    1.000010e+11    116.000000  ...        1.000000          1.000000
#
# [8 rows x 19 columns]

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# Serão considerados somente os cliente pré aprovados, confrome o enunciado do problema.

# %%
sns.countplot(x='pre_approved', data=df).set_title('Pre Approved Distribution');

# %%
df = df.query('pre_approved == 1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14999 entries, 7 to 35019
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    14999 non-null  int64
#  1   age                   14999 non-null  float64
#  2   monthly_income        14999 non-null  float64
#  3   collateral_value      14986 non-null  float64
#  4   loan_amount           14999 non-null  float64
#  5   city                  14991 non-null  object
#  6   state                 14999 non-null  object
#  7   collateral_debt       9692 non-null   float64
#  8   verified_restriction  14935 non-null  float64
#  9   dishonored_checks     14999 non-null  int64
#  10  expired_debts         14999 non-null  int64
#  11  banking_debts         14999 non-null  int64
#  12  commercial_debts      14999 non-null  int64
#  13  protests              14999 non-null  int64
#  14  marital_status        402 non-null    object
#  15  informed_restriction  14193 non-null  float64
#  16  loan_term             0 non-null      float64
#  17  monthly_payment       14249 non-null  float64
#  18  informed_purpose      14416 non-null  object
#  19  auto_brand            14999 non-null  object
#  20  auto_model            14998 non-null  object
#  21  auto_year             14999 non-null  float64
#  22  pre_approved          14999 non-null  float64
#  23  form_completed        14999 non-null  float64
#  24  sent_to_analysis      14999 non-null  float64
#  25  channel               14434 non-null  object
#  26  zip_code              14999 non-null  object
#  27  landing_page          14434 non-null  object
#  28  landing_page_product  9294 non-null   object
#  29  gender                13107 non-null  object
#  30  utm_term              4774 non-null   object
#  31  education_level       12112 non-null  object
# dtypes: float64(13), int64(6), object(13)
# memory usage: 3.8+ MB

# %%
df.isnull().sum()
# Out:
# id                          0
# age                         0
# monthly_income              0
# collateral_value           13
# loan_amount                 0
# city                        8
# state                       0
# collateral_debt          5307
# verified_restriction       64
# dishonored_checks           0
# expired_debts               0
# banking_debts               0
# commercial_debts            0
# protests                    0
# marital_status          14597
# informed_restriction      806
# loan_term               14999
# monthly_payment           750
# informed_purpose          583
# auto_brand                  0
# auto_model                  1
# auto_year                   0
# pre_approved                0
# form_completed              0
# sent_to_analysis            0
# channel                   565
# zip_code                    0
# landing_page              565
# landing_page_product     5705
# gender                   1892
# utm_term                10225
# education_level          2887
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis / EDA

# %% [markdown]
# Será analisados a contagem das variáveis: gender, sent to analysis e form completed. Também será verificado a distribuição de variáveis com muitos valores distintos, afim de verificar outiliers.

# %% [markdown]
# ## Count Analysis

# %%
sns.countplot(x='gender', data=df).set_title('Gender Distribution');

# %%
sns.countplot(x='sent_to_analysis', data=df).set_title('Sent to Analysis Distribution');

# %%
sns.countplot(x='form_completed', data=df).set_title('Form Completed Distribution');

# %%
g = sns.countplot(x='education_level', data=df);
g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("", fontsize=5)
g.set_ylabel("Count", fontsize=10)
g.set_title("Education Level Count", fontsize=15);

# %%
sns.histplot(data=df, x="age", kde=True, bins=20);

# %% [markdown]
# ## Exploratoring Outliers

# %% [markdown]
# Serão analisadas as distribuições EDA das seguintes variáveis: age, auto_year, monthly_income, collateral_value

# %%
ax = sns.boxplot(x=df["age"]);

# %%
sns.boxplot(x=df["monthly_income"]).set_title('Monthly Income Distribution');

# %%
sns.boxplot(x=df["auto_year"]).set_title('Auto Year Distribution');

# %%
sns.boxplot(x=df["collateral_value"]).set_title('Collateral Value Distribution');

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Deleting Collumns

# %% [markdown]
# Serão excluidas as colunas marital_status e loan_term devido a ambas possuirem muitos valores nulos.
#
# Será excluída a coluna gender dada que é uma coluna desbalanceada e continuar com ela enviesará o modelo devido ao genero.

# %%
df = df.drop(columns=['marital_status'])

# %%
df = df.drop(columns=['loan_term'])

# %%
df = df.drop(columns=['gender'])

# %% [markdown]
# ## Cleaning Outiliers

# %% [markdown]
# **zscore** ver para definir determinação de limpeza dos outliers

# %%
from scipy import stats

# %%
stats.zscore(df['age'])
# Out:
# array([ 1.17548166, -1.58307393,  0.83066221, ..., -0.37620586,
#        -1.23825448,  1.00307194])

# %% [markdown]
# Retirada as idades acima de 75 anos, pois clientes acima de 75 anos não estão dentro da politica da creditas.

# %%
df = df.query('age < 75')

# %%
sns.boxplot(x=df["age"]);

# %% [markdown]
# Considerado os clientes com renda abaixo de R$300.000, pois um cliente com uma renda cima disso muito provavelmente não irá realizar um empréstimo com um produto com o carro em garantia.

# %%
df = df.query('monthly_income < 300000')

# %%
sns.boxplot(x=df["monthly_income"]).set_title('Monthly Income Distribution');

# %% [markdown]
# Considerado os automóveis acima de 2002, pois são aceitos na política da Creditas garanitas com no máximo 15 anos e dados tem garantias que são de no máximo 2017.

# %%
df = df.query('auto_year >= 2002')

# %%
sns.boxplot(x=df["auto_year"]).set_title('Auto Year Distribution');

# %% [markdown]
# Considerado os clientes com renda abaixo de R$500.000, pois um cliente com uma garantia cima disso muito provavelmente não irá realizar um empréstimo com um produto com o carro em garantia. Além disso, garantias de carros de luxo com esse valor, como Ferrari ou Lamborguini não são aceitos dentro da política.

# %%
df = df.query('collateral_value <= 500000')

# %%
sns.boxplot(x=df["collateral_value"]).set_title('Collateral Value Distribution');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14671 entries, 7 to 35019
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    14671 non-null  int64
#  1   age                   14671 non-null  float64
#  2   monthly_income        14671 non-null  float64
#  3   collateral_value      14671 non-null  float64
#  4   loan_amount           14671 non-null  float64
#  5   city                  14663 non-null  object
#  6   state                 14671 non-null  object
#  7   collateral_debt       9477 non-null   float64
#  8   verified_restriction  14609 non-null  float64
#  9   dishonored_checks     14671 non-null  int64
#  10  expired_debts         14671 non-null  int64
#  11  banking_debts         14671 non-null  int64
#  12  commercial_debts      14671 non-null  int64
#  13  protests              14671 non-null  int64
#  14  informed_restriction  13887 non-null  float64
#  15  monthly_payment       13934 non-null  float64
#  16  informed_purpose      14093 non-null  object
#  17  auto_brand            14671 non-null  object
#  18  auto_model            14670 non-null  object
#  19  auto_year             14671 non-null  float64
#  20  pre_approved          14671 non-null  float64
#  21  form_completed        14671 non-null  float64
#  22  sent_to_analysis      14671 non-null  float64
#  23  channel               14121 non-null  object
#  24  zip_code              14671 non-null  object
#  25  landing_page          14121 non-null  object
#  26  landing_page_product  9074 non-null   object
#  27  utm_term              4705 non-null   object
#  28  education_level       11879 non-null  object
# dtypes: float64(12), int64(6), object(11)
# memory usage: 3.4+ MB

# %%
df.isnull().sum()
# Out:
# id                         0
# age                        0
# monthly_income             0
# collateral_value           0
# loan_amount                0
# city                       8
# state                      0
# collateral_debt         5194
# verified_restriction      62
# dishonored_checks          0
# expired_debts              0
# banking_debts              0
# commercial_debts           0
# protests                   0
# informed_restriction     784
# monthly_payment          737
# informed_purpose         578
# auto_brand                 0
# auto_model                 1
# auto_year                  0
# pre_approved               0
# form_completed             0
# sent_to_analysis           0
# channel                  550
# zip_code                   0
# landing_page             550
# landing_page_product    5597
# utm_term                9966
# education_level         2792
# dtype: int64

# %%
df.groupby(['id']).size()
# Out:
# id
# 98327     1
# 98333     1
# 98335     1
# 98337     1
# 98339     1
#          ..
# 173437    1
# 173442    1
# 173450    1
# 173455    1
# 173460    1
# Length: 14670, dtype: int64

# %%
df.nunique().sort_values()
# Out:
# pre_approved                1
# informed_restriction        2
# sent_to_analysis            2
# form_completed              2
# protests                    2
# verified_restriction        2
# dishonored_checks           2
# expired_debts               2
# banking_debts               2
# commercial_debts            2
# utm_term                    3
# landing_page_product        7
# channel                     9
# education_level             9
# auto_year                  16
# state                      27
# auto_brand                 51
# age                        57
# landing_page              186
# collateral_debt           718
# loan_amount              1003
# monthly_income           1430
# auto_model               1547
# collateral_value         1647
# city                     2194
# monthly_payment          2296
# zip_code                 4352
# informed_purpose         8146
# id                      14670
# dtype: int64

# %%
df['id'].duplicated().sum()
# Out:
# 1

# %%
df.id.duplicated().sum()
# Out:
# 1

# %% [markdown]
# onehotencoder
# OrdinalEncoder

# %%
from sklearn import preprocessing

# %%
label_enconder = preprocessing.LabelEncoder()

# %%
df['education_level']= label_enconder.fit_transform(df['education_level'])

# %%
df.head()
# Out:
#         id   age  monthly_income  ...  landing_page_product  utm_term education_level
# 7   173460  52.0          5668.0  ...          PersonalLoan       NaN               7
# 11  173455  20.0          5000.0  ...                   NaN       NaN               7
# 13  173450  48.0          3000.0  ...                   NaN       NaN               4
# 18  173442  56.0          7500.0  ...          PersonalLoan       NaN               9
# 22  173437  35.0          3379.0  ...          PersonalLoan       NaN               7
#
# [5 rows x 29 columns]
